# %% [markdown]
# # Loading Libray

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import r2_score

# %% [markdown]
# # Importing dataset after EDA is done

# %%
data = pd.read_csv(r"C:\Users\HP\Documents\final_df_after_eda_IPL_pred.csv")
data
# Out:
#            runs   wickets     overs  total  date  venue  bat_team  bowl_team  \
# 0     -1.513413 -1.198815 -1.677434    222    79     14         6         12
# 1     -1.513413 -1.198815 -1.660110    222    79     14         6         12
# 2     -1.492930 -1.198815 -1.660110    222    79     14         6         12
# 3     -1.492930 -1.198815 -1.642787    222    79     14         6         12
# 4     -1.492930 -1.198815 -1.625464    222    79     14         6         12
# ...         ...       ...       ...    ...   ...    ...       ...        ...
# 76009  0.944445  2.274797  1.631330    129   339     23         7         10
# 76010  1.067338  2.274797  1.648653    129   339     23         7         10
# 76011  1.087820  2.274797  1.665977    129   339     23         7         10
# 76012  1.108302  2.274797  1.683300    129   339     23         7         10
# 76013  1.108302  2.771027  1.700624    129   339     23         7         10
#
#        batsman  bowler
# ...

# %% [markdown]
# # Spiliting x and y

# %%
# Sepratating & assigning features and target columns to x & y respectively

y = data['total']
x = data.drop('total',axis=1)

# %%
x
# Out:
#            runs   wickets     overs  date  venue  bat_team  bowl_team  \
# 0     -1.513413 -1.198815 -1.677434    79     14         6         12
# 1     -1.513413 -1.198815 -1.660110    79     14         6         12
# 2     -1.492930 -1.198815 -1.660110    79     14         6         12
# 3     -1.492930 -1.198815 -1.642787    79     14         6         12
# 4     -1.492930 -1.198815 -1.625464    79     14         6         12
# ...         ...       ...       ...   ...    ...       ...        ...
# 76009  0.944445  2.274797  1.631330   339     23         7         10
# 76010  1.067338  2.274797  1.648653   339     23         7         10
# 76011  1.087820  2.274797  1.665977   339     23         7         10
# 76012  1.108302  2.274797  1.683300   339     23         7         10
# 76013  1.108302  2.771027  1.700624   339     23         7         10
#
#        batsman  bowler
# 0          328     201
# 1           61     201
# 2           61     201
# 3           61     201
# ...

# %%
y
# Out:
# 0        222
# 1        222
# 2        222
# 3        222
# 4        222
#         ...
# 76009    129
# 76010    129
# 76011    129
# 76012    129
# 76013    129
# Name: total, Length: 76014, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3,random_state=42)

# %% [markdown]
# # Train model with XGBRegressor because its gives highest accuracy

# %%
xgb = XGBRegressor()

# %%
xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = xgb.predict(x_train)
Train_Accuracy = r2_score(y_pred, y_train)
Train_Accuracy
# Out:
# 0.9467849376062256

# %%
print('Accuracy score of the training data : ', round(Train_Accuracy*100,4),"%")
# Out:
# Accuracy score of the training data :  94.6785 %

# %%
y_pred_test = xgb.predict(x_test)
Test_Accuracy = r2_score(y_pred_test , y_test)
Test_Accuracy
# Out:
# 0.9313470188359427

# %%
print('Accuracy score of the test data : ', round(Test_Accuracy*100,4),"%")
# Out:
# Accuracy score of the test data :  93.1347 %

# %%
print(x_test)
# Out:
#            runs   wickets     overs  date  venue  bat_team  bowl_team  \
# 12590 -1.513413 -0.206355 -1.486877   309     18         2         12
# 74893  1.149267  0.289876  0.782485   244      9         3          2
# 56763 -0.796537  0.289876 -0.551415    76     34         7          0
# 19428  0.596249  0.289876  0.643898    42      1         7          2
# 30216  0.575766  0.786106  0.609251   212      5         0          1
# ...         ...       ...       ...   ...    ...       ...        ...
# 52464  0.391427 -0.206355  0.418694   268     14        12          2
# 23921  0.473356 -1.198815 -0.274241   129      8         2          4
# 24202  0.104677  0.289876  0.747838   139     26         5          9
# 61097 -0.817020 -0.206355 -0.897882   293     22         4          0
# 62584 -0.530269 -0.702585 -0.776618    54     25        11          3
#
#        batsman  bowler
# 12590      122     128
# 74893      171      72
# 56763      133     228
# 19428      350     210
# ...

# %%
print('Actual Values of Y Test are: \n',np.array(y_test))
# Out:
# Actual Values of Y Test are:
#  [134 195 183 ... 109 130 163]

# %%
print('Predicted Values of Y Test are: \n', y_pred_test)
# Out:
# Predicted Values of Y Test are:
#  [133.4004  189.99197 168.89066 ... 118.98387 135.50667 165.61618]

# %% [markdown]
# # Making a Predictive System

# %%
input_data = [-1.5134,-0.2063,-1.4868,309,18,2,12,122,128]

# changing the input_data list into numpy array
input_data_as_numpy_array = np.array(input_data)

# reshape the array into 1 row and all columns-type,  as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

print(input_data_reshaped)
# Out:
# [[-1.5134e+00 -2.0630e-01 -1.4868e+00  3.0900e+02  1.8000e+01  2.0000e+00
#    1.2000e+01  1.2200e+02  1.2800e+02]]

# %%
input_data = [-1.5134,-0.2063,-1.4868,309,18,2,12,122,128]

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array into 1 row and all columns-type,  as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = xgb.predict(input_data_reshaped)
print(f"IPL match runs count prediction for given data is : {prediction}")
# Out:
# IPL match runs count prediction for given data is : [133.4004]

# %% [markdown]
# # Saving the Trained Model:

# %%
import pickle

# %%
filename = 'IPL_trained_model.sav'
pickle.dump(xgb, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('IPL_trained_model.sav', 'rb'))

# %%
input_data = [ 0.39142,-0.2063,0.4186,268,14,12,2,19,191]

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array into 1 row and all columns-type,  as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = xgb.predict(input_data_reshaped)
print(f"IPL match runs count prediction for given data is : {prediction}")
# Out:
# IPL match runs count prediction for given data is : [188.21222]
