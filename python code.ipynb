# %%
import pandas as pd 
import requests 
from bs4 import BeautifulSoup

# %%
url = "https://www.flipkart.com/wings-phantom-pro-earbuds-low-latency-game-mode-40h-playtime-50ms-bluetooth-headset/p/itm9ceff01aba2bd?pid=ACCG4XTZKH5GFPVD&lid=LSTACCG4XTZKH5GFPVDMSCXQO&marketplace=FLIPKART&q=wings+earbuds&store=0pm%2Ffcn%2F821%2Fa7x%2F2si&srno=s_1_9&otracker=AS_QueryStore_OrganicAutoSuggest_2_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_6_na_na_na&fm=search-autosuggest&iid=2c2e01f0-7282-4577-b1c5-629d4d8a3c51.ACCG4XTZKH5GFPVD.SEARCH&ppt=sp&ppn=sp&ssid=l776l8ow1s0000001701497279431&qH=13dab9d5b821e0eb"

# %%
r =requests.get(url)
data =r.content
print(data)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
#prettify the codes of html page
soup =BeautifulSoup(data, "html.parser")
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
title =soup.title
print(type(soup))          #beautifulsoup
print(type(title))         #tag
print(type(title.string))  #navigablestring
# Out:
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>

# %%
title = soup.title
title
# Out:
# <title>Wings Phantom Pro earbuds with Low latency Game mode, 40H Playtime, 50ms low latency Bluetooth Headset Price in India - Buy Wings Phantom Pro earbuds with Low latency Game mode, 40H Playtime, 50ms low latency Bluetooth Headset Online - Wings : Flipkart.com</title>

# %%
price =soup.find_all(class_="_30jeq3 _16Jk6d")
price
# Out:
# [<div class="_30jeq3 _16Jk6d">₹1,099</div>]

# %%
price[0].get_text()
# Out:
# '₹1,099'

# %%
names =soup.find_all(class_="_2sc7ZR _2V5EHH")
names =list(names)
print (type(names))
print(names)
len(names)
# Out:
# <class 'list'>
# [<p class="_2sc7ZR _2V5EHH">saif ali khan</p>, <p class="_2sc7ZR _2V5EHH">Ankit Sahoo</p>, <p class="_2sc7ZR _2V5EHH">Sohail Khan</p>, <p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>, <p class="_2sc7ZR _2V5EHH">Julen Nath</p>, <p class="_2sc7ZR _2V5EHH">Ashwani Kumar</p>, <p class="_2sc7ZR _2V5EHH">Sahil</p>, <p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>, <p class="_2sc7ZR _2V5EHH">Akash Patke </p>, <p class="_2sc7ZR _2V5EHH">Suvam Paul</p>]
# 10

# %%
names[0].get_text()
# Out:
# 'saif ali khan'

# %%
c_names=[]
for i in names:
    c_names.append(i.get_text())
c_names
# Out:
# ['saif ali khan',
#  'Ankit Sahoo',
#  'Sohail Khan',
#  'Flipkart Customer',
#  'Julen Nath',
#  'Ashwani Kumar',
#  'Sahil',
#  'Flipkart Customer',
#  'Akash Patke ',
#  'Suvam Paul']

# %%
comment =soup.find_all(class_ ="_2-N8zT")
print(len(comment))
# Out:
# 10

# %%
review_comment =[]
for i in comment:
    review_comment.append(i.get_text())
review_comment
# Out:
# ['Nice product',
#  'Wonderful',
#  'Awesome',
#  'Highly recommended',
#  'Value-for-money',
#  'Good choice',
#  'Highly recommended',
#  'Highly recommended',
#  'Classy product',
#  'Worth every penny']

# %%
stars =soup.find_all('div', class_ ="_3LWZlK _1BLPMq")
print(stars)
# Out:
# [<div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>, <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>]

# %%
s_stars =[]
for i in stars:
    s_stars. append (i.get_text())
s_stars
# Out:
# ['4', '5', '5', '5', '4', '4', '5', '5', '5', '5']

# %%
review = soup.find_all('div',class_ ="t-ZTKy")
print(review)
# Out:
# [<div class="t-ZTKy"><div><div class="">Pros - <br/>1. Highly recommended Budget Gaming TWS.<br/>2. Sound quality is good in this price range.<br/>3. Gaming lights look awesome <br/>4. Latency in gaming mode is the lowest.<br/>5. Battery backup is awesome. <br/><br/>Cons - <br/>1. Difficulty in opening the case can be seen. <br/>2. While playing PUBG difficulty in understanding the footsteps direction. <br/>3. Starts paining on the left ear, don't know if it's only for me. <br/><br/>Overall a good budget gaming TWS in this range.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>, <div class="t-ZTKy"><div><div class="">Good design good product</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>, <div class="t-ZTKy"><div><div class="">Good for gaming 😄</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>, <div class="t-ZTKy"><div><div class="">It's all awesome 😎<br/>More than i expected 💘</div><span class="_1H-bmy"><span>READ MORE</sp
# ...

# %%
cust_review =[]
for i in review:
    cust_review.append(i.get_text())
cust_review
# Out:
# ["Pros - 1. Highly recommended Budget Gaming TWS.2. Sound quality is good in this price range.3. Gaming lights look awesome 4. Latency in gaming mode is the lowest.5. Battery backup is awesome. Cons - 1. Difficulty in opening the case can be seen. 2. While playing PUBG difficulty in understanding the footsteps direction. 3. Starts paining on the left ear, don't know if it's only for me. Overall a good budget gaming TWS in this range.READ MORE",
#  'Good design good productREAD MORE',
#  'Good for gaming 😄READ MORE',
#  "It's all awesome 😎More than i expected 💘READ MORE",
#  "My personal opinion sound quality is very good.Bass is awesome 👍.Calling is excellent work but gaming mode is not good .Not working in the same firing mode.Battery backup very good 👍.Music lovers by this product. Gaming lover don't by this product.READ MORE",
#  'Value for moneyREAD MORE',
#  'Unique design solid build qualityREAD MORE',
# ...

# %%
import pandas as pd

# %%
df= pd.DataFrame({"customers_Name":c_names,"Review_Comment":review_comment,"review_stars":s_stars,"review":cust_review})
df
# Out:
#       customers_Name      Review_Comment review_stars  \
# 0      saif ali khan        Nice product            4
# 1        Ankit Sahoo           Wonderful            5
# 2        Sohail Khan             Awesome            5
# 3  Flipkart Customer  Highly recommended            5
# 4         Julen Nath     Value-for-money            4
# 5      Ashwani Kumar         Good choice            4
# 6              Sahil  Highly recommended            5
# 7  Flipkart Customer  Highly recommended            5
# 8       Akash Patke       Classy product            5
# 9         Suvam Paul   Worth every penny            5
#
#                                               review
# 0  Pros - 1. Highly recommended Budget Gaming TWS...
# 1                  Good design good productREAD MORE
# 2                         Good for gaming 😄READ MORE
# 3  It's all awesome 😎More than i expected 💘READ MORE
# 4  My personal opinion sound quality is very good...
# ...

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\HP'

# %%
df.to_csv("wings_earbuds.csv",index= False )
df1= pd.read_csv("wings_earbuds.csv")
df1
# Out:
#       customers_Name      Review_Comment  review_stars  \
# 0      saif ali khan        Nice product             4
# 1        Ankit Sahoo           Wonderful             5
# 2        Sohail Khan             Awesome             5
# 3  Flipkart Customer  Highly recommended             5
# 4         Julen Nath     Value-for-money             4
# 5      Ashwani Kumar         Good choice             4
# 6              Sahil  Highly recommended             5
# 7  Flipkart Customer  Highly recommended             5
# 8       Akash Patke       Classy product             5
# 9         Suvam Paul   Worth every penny             5
#
#                                               review
# 0  Pros - 1. Highly recommended Budget Gaming TWS...
# 1                  Good design good productREAD MORE
# 2                         Good for gaming 😄READ MORE
# 3  It's all awesome 😎More than i expected 💘READ MORE
# 4  My personal opinion sound quality is very good...
# ...

# %%
df.to_csv("wings_earbuds.csv")

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\HP'

# %%
df1.describe()
# Out:
#        review_stars
# count     10.000000
# mean       4.700000
# std        0.483046
# min        4.000000
# 25%        4.250000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customers_Name  10 non-null     object
#  1   Review_Comment  10 non-null     object
#  2   review_stars    10 non-null     int64
#  3   review          10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 452.0+ bytes

# %%
df1.customers_Name.sort_values()
# Out:
# 8         Akash Patke
# 1          Ankit Sahoo
# 5        Ashwani Kumar
# 3    Flipkart Customer
# 7    Flipkart Customer
# 4           Julen Nath
# 6                Sahil
# 2          Sohail Khan
# 9           Suvam Paul
# 0        saif ali khan
# Name: customers_Name, dtype: object

# %%
df1.customers_Name.sort_values(ascending=False)
# Out:
# 0        saif ali khan
# 9           Suvam Paul
# 2          Sohail Khan
# 6                Sahil
# 4           Julen Nath
# 3    Flipkart Customer
# 7    Flipkart Customer
# 5        Ashwani Kumar
# 1          Ankit Sahoo
# 8         Akash Patke
# Name: customers_Name, dtype: object

# %%
df1[df1.review_stars==5]
# Out:
#       customers_Name      Review_Comment  review_stars  \
# 1        Ankit Sahoo           Wonderful             5
# 2        Sohail Khan             Awesome             5
# 3  Flipkart Customer  Highly recommended             5
# 6              Sahil  Highly recommended             5
# 7  Flipkart Customer  Highly recommended             5
# 8       Akash Patke       Classy product             5
# 9         Suvam Paul   Worth every penny             5
#
#                                               review
# 1                  Good design good productREAD MORE
# 2                         Good for gaming 😄READ MORE
# 3  It's all awesome 😎More than i expected 💘READ MORE
# 6         Unique design solid build qualityREAD MORE
# 7  Good product light is good but case opening is...
# 8  Honestly, one of the best product available in...
# 9                                Osm look😍😍READ MORE

# %%
df1[df1.review_stars<5]
# Out:
#   customers_Name   Review_Comment  review_stars  \
# 0  saif ali khan     Nice product             4
# 4     Julen Nath  Value-for-money             4
# 5  Ashwani Kumar      Good choice             4
#
#                                               review
# 0  Pros - 1. Highly recommended Budget Gaming TWS...
# 4  My personal opinion sound quality is very good...
# 5                           Value for moneyREAD MORE
